# %% [markdown]
# ### Quasi optics - on-axis calculations of EXCLAIM optics
# In this code we estimate analytically the on-axis calculations for the EXCLAIM optics, simulating the mirrors with lenses of equivalent focal length. We will later perform the Fresnel diffraction calculations using PoPPy code.
#
# This block goes utilizes Gaussian optics calculations in Goldsmith (1998) -- see the summary here in the 'Gaussian Beam Optics' section: https://www.overleaf.com/read/gykryddxcnhh
#
# Goal: -40dB at 15deg for primary
# -30dB at 15deg for secondary

# %%
import numpy as np
import matplotlib.pyplot as plt

import astropy.units as u
from astropy import constants as const
from astropy.units import cds
cds.enable()  

from scipy.special import i0, k0

import copy

figsize = (15,10)
figsize_small=(10,6)

# %%
import poppy
# %pylab inline --no-import-all
matplotlib.rcParams['image.origin'] = 'lower'
poppy.__version__
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /opt/anaconda3/envs/main/lib/python3.7/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['figsize']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"
# '0.9.1'

# %% [markdown]
# EXCLAIM optics parameters (all in cm):

# %%
# effective focal lengths of tertiary, secondary, primary
f_1 = 155 * u.cm
f_2 = 11940 * u.cm
f_3 = 19.2 * u.cm

f_lens = 24 * u.cm

# waist at lenslet. From Negar's slides on the lenslet. Output at ~500GHz
# 420GHz: 1.618mm
# 470GHz: 1.616mm
# 480GHz: 1.680mm
# 520GHz: 1.715mm
# 540GHz: 1.708mm

w_0_lenslet = .17 * u.cm 

# CST simulation positions (y,z):
lens_top_position = [-84.67,-51.06] * u.cm
tertiary_position = [-84.67,-18] * u.cm
secondary_position = [0.,0.] * u.cm
primary_position = [-98.67,35.89] * u.cm

d_lenslet_lens = 24 * u.cm
d_lens_3 = ((lens_top_position[0]-tertiary_position[0])**2+(lens_top_position[1]-tertiary_position[1])**2)**.5
d_3_2 = ((secondary_position[0]-tertiary_position[0])**2+(secondary_position[1]-tertiary_position[1])**2)**.5
d_2_1 = ((secondary_position[0]-primary_position[0])**2+(secondary_position[1]-primary_position[1])**2)**.5

d_lens_3 = d_lens_3.to(u.cm)
d_3_2 = d_3_2.to(u.cm)
d_2_1 = d_2_1.to(u.cm)

print("Distances:")
print("\tLenslet-lens: %.3f cm" %d_lenslet_lens.value)
print("\tLens-tertiary: %.3f cm" %d_lens_3.value)
print("\tTertiary-secondary: %.3f cm" %d_3_2.value)
print("\tSecondary-primary: %.3f cm" %d_2_1.value)

waist_3 = 17.53021265771928*u.cm
# Out:
# Distances:
# 	Lenslet-lens: 24.000 cm
# 	Lens-tertiary: 33.060 cm
# 	Tertiary-secondary: 86.562 cm
# 	Secondary-primary: 104.995 cm

# %%
ff = 480*u.GHz#500*u.GHz
ll = const.c/ff

# %% [markdown]
# # Poppy calculations

# %%
plot_widths = False
width_array = [] # append for each step_dist for plot of width sizes
step_dist = 0.01 * u.cm

# %% [markdown]
# ## Initialize objects for optical elements

# %% [markdown]
# # Waist at lens, initialize Gaussian w/ FWHM=waist

# %%
fwhm_ = np.sqrt(np.log(2)/297.4178) * u.m
w_lens = 2.71*u.cm
cold_stop_radius = 0.0381*u.m

lens_aperture = poppy.GaussianAperture(fwhm=fwhm_)
lens_obj = poppy.QuadraticLens(f_lens)
tertiary_obj = poppy.QuadraticLens(f_3)
secondary_obj = poppy.QuadraticLens(f_2)
primary_obj = poppy.QuadraticLens(f_1)

ring = poppy.CircularAperture(radius=cold_stop_radius)

# %%
baffle_spacing = 0.00064*u.m
baffle = poppy.CircularAperture(radius=(cold_stop_radius + baffle_spacing))

# all in inches
baffle_z_array = [0.350,
        0.700,
        1.050,
        2.150,
        2.500,
        2.850,
        3.950,
        4.300,
        4.650]

for i,baffle_z in enumerate(baffle_z_array):
    baffle_z_array[i] = (baffle_z*u.cds.inch).to(u.cm)

# %%
baffle_IF_rad = 4*u.cm
baffle_IF = poppy.CircularAperture(radius=baffle_IF_rad)

# %%
w_extent = 3

wf = poppy.FresnelWavefront(beam_radius=w_lens*w_extent, wavelength=ll)#,npix=4096)

wf *= lens_aperture

wf *= ring # cold stop

print("After aperture, beam waist is at {}".format(wf.z_w0) )

plt.figure(figsize=(10,5))
wf.display('both', colorbar=True);
plt.suptitle("Wavefront after passing through lens aperture", fontsize=18);
# Out:
# After aperture, beam waist is at 0.0 m

# %%
y_lens, x_lens = wf.coordinates()
z_lens = wf.intensity
array_length = z_lens.shape[0]
half_array_length = int(z_lens.shape[0]/2)

fig = plt.figure(figsize=figsize_small)
plt.plot(x_lens[half_array_length,half_array_length:]*100,10*np.log10(z_lens[half_array_length,half_array_length:]),
         label='Post-lens')
plt.xlabel('Distance from center (cm)')
plt.ylabel('Transmission (dB)')
#plt.yscale('log')
plt.legend()
plt.show()
# Out:
# /opt/anaconda3/envs/main/lib/python3.7/site-packages/ipykernel_launcher.py:7: RuntimeWarning: divide by zero encountered in log10
#   import sys

# %%
if plot_widths:
    for mm in range(int(round(d_lens_3.value,2)/step_dist.value)):
        if mm%100==0:
            print(mm*step_dist)
        wf.propagate_fresnel(step_dist)
        width_array.append(wf.spot_radius().to(u.cm))
else:
    wf_b = copy.deepcopy(wf)
    
    # wf no baffles:
    wf.propagate_fresnel(d_lens_3)
    
    # wf w/ baffles
    baffle_distance_sum = 0
    for i,baffle_z in enumerate(baffle_z_array):
        if i==0:
            wf_b.propagate_fresnel(baffle_z)
        else:
            wf_b.propagate_fresnel(baffle_z-baffle_z_array[i-1])
        wf_b*=baffle
        
    wf_b.propagate_fresnel(d_lens_3-baffle_z_array[-1])
    
    z_3_b = wf_b.intensity
    
    y_3_b,x_3_b = wf_b.coordinates()

y_3, x_3 = wf.coordinates()
z_3 = wf.intensity

array_length = z_3.shape[0]
half_array_length = int(z_3.shape[0]/2)

# %%
fig2 = plt.figure(figsize=figsize_small)
plt.plot(x_3[half_array_length,half_array_length:]*100,
         10*np.log10(z_3[half_array_length,half_array_length:]),
         label='No baffles')
if not plot_widths:
    plt.plot(x_3_b[half_array_length,half_array_length:]*100,
             10*np.log10(z_3_b[half_array_length,half_array_length:]),
             label='Baffles')
    
plt.xlabel('Distance from center (cm)')
plt.ylabel('Transmission (dB)')
plt.title('Beam at tertiary')
plt.legend()
plt.show()

# %%
wf*=tertiary_obj

if not plot_widths:
    wf_b*=tertiary_obj
    
waist_post_tertiary = wf.z_w0-d_lens_3

waist_3 = waist_post_tertiary
print(waist_post_tertiary)
# Out:
# 0.19199359822615158 m

# %%
if plot_widths:
    for mm in range(int(round(d_3_2.value,2)/step_dist.value)):
        if mm%100==0:
            print(mm*step_dist)
        wf.propagate_fresnel(step_dist)
        width_array.append(wf.spot_radius().to(u.cm))
else:
    wf_0_b = copy.deepcopy(wf)
    wf_b_b = copy.deepcopy(wf_b)
    
    wf.propagate_fresnel(d_3_2)
    wf_b.propagate_fresnel(d_3_2)
    #wf_0_b.propagate_fresnel(d_3_2)
    #wf_b_b.propagate_fresnel(d_3_2)
    
    wf_0_b.propagate_fresnel(waist_3)
    wf_0_b*=baffle_IF
    wf_0_b.propagate_fresnel(d_3_2-waist_3)
    
    wf_b_b.propagate_fresnel(waist_3)
    wf_b_b*=baffle_IF
    wf_b_b.propagate_fresnel(d_3_2-waist_3)
    
    z_2_b = wf_b.intensity
    z_2_0_b = wf_0_b.intensity
    z_2_b_b = wf_b_b.intensity
    
    y_2_b,x_2_b = wf_b.coordinates()
    y_2_0_b,x_2_0_b = wf_0_b.coordinates()
    y_2_b_b,x_2_b_b = wf_b_b.coordinates()
    
    d_waist = (d_3_2.to(u.m) - waist_3.to(u.m))
    plot_angle_array_b = np.arctan(np.array(x_2_b[half_array_length,half_array_length:]/d_waist.value))*180/np.pi
    plot_angle_array_0_b = np.arctan(np.array(x_2_0_b[half_array_length,half_array_length:]/d_waist.value))*180/np.pi
    plot_angle_array_b_b = np.arctan(np.array(x_2_b_b[half_array_length,half_array_length:]/d_waist.value))*180/np.pi

y_2, x_2 = wf.coordinates()
z_2 = wf.intensity
array_length = z_2.shape[0]
half_array_length = int(z_2.shape[0]/2)

if z_2.shape!=z_2_b.shape or z_2.shape!=z_2_0_b.shape or z_2.shape!=z_2_b_b.shape:
    print("Warning: shapes don't match!")

plot_angle_array = np.arctan(np.array(x_2[half_array_length,half_array_length:])/d_waist.value)*180/np.pi

# %%
fig3 = plt.figure(figsize=figsize_small)
plt.plot(x_2[half_array_length,half_array_length:]*100,10*np.log10(z_2[half_array_length,half_array_length:]),
         label='No baffle, no T-rex',linestyle='--')
if not plot_widths:
    plt.plot(x_2_b[half_array_length,half_array_length:]*100,10*np.log10(z_2_b[half_array_length,half_array_length:]),
             label='Baffles, no T-rex',linestyle='--')
    plt.plot(x_2_0_b[half_array_length,half_array_length:]*100,10*np.log10(z_2_0_b[half_array_length,half_array_length:]),
             label='No baffles + T-rex')
    plt.plot(x_2_b_b[half_array_length,half_array_length:]*100,10*np.log10(z_2_b_b[half_array_length,half_array_length:]),
             label='Baffles + T-rex')
plt.axhline(y=-30,label='Target at 15 degrees',linestyle=':')

plt.xlim((0,20))
plt.ylim((-45,5))
#plt.xlabel('Angle (degrees)')
plt.xlabel('Distance from Center (cm)')
plt.ylabel('Transmission (dB)')
plt.title('Beam at secondary')
#plt.yscale('log')
plt.legend(loc='lower left')
plt.show()

# %%
fig3 = plt.figure(figsize=figsize_small)
plt.plot(100*x_2[half_array_length,half_array_length:],(z_2[half_array_length,half_array_length:]),
         label='No baffles, no T-rex',linestyle='--')
if not plot_widths:
    plt.plot(100*x_2_b[half_array_length,half_array_length:],(z_2_b[half_array_length,half_array_length:]),
         label='Baffles, no T-rex',linestyle='--')
    plt.plot(100*x_2_0_b[half_array_length,half_array_length:],(z_2_0_b[half_array_length,half_array_length:]),
         label='No baffles + T-rex')
    plt.plot(100*x_2_b_b[half_array_length,half_array_length:],(z_2_b_b[half_array_length,half_array_length:]),
         label='Baffles + T-rex')
#plt.axhline(y=-40,label='Target at 15 degrees',linestyle=':')
plt.xlabel('Distance from center (cm)')
#plt.xlabel('Distance (cm)')
plt.ylabel('Fraction of transmitted power (linear scale)')
plt.xlim((0,5))
#plt.ylim((-60,5))
#plt.yscale('log')
plt.title('Beam post-secondary')
plt.legend()
plt.show()

# %%
wf*=secondary_obj
if not plot_widths:
    wf_b*=secondary_obj
    wf_0_b*=secondary_obj
    wf_b_b*=secondary_obj

# %%
if plot_widths:
    for mm in range(int(round(d_2_1.value,2)/step_dist.value)):
        if mm%100==0:
            print(mm*step_dist)
        wf.propagate_fresnel(step_dist)
        width_array.append(wf.spot_radius().to(u.cm))
else:
    wf.propagate_fresnel(d_2_1)
    wf_b.propagate_fresnel(d_2_1)
    wf_0_b.propagate_fresnel(d_2_1)
    wf_b_b.propagate_fresnel(d_2_1)
    
    z_1_b = wf_b.intensity
    z_1_0_b = wf_0_b.intensity
    z_1_b_b = wf_b_b.intensity
    
    y_1_b,x_1_b = wf_b.coordinates()
    y_1_0_b,x_1_0_b = wf_0_b.coordinates()
    y_1_b_b,x_1_b_b = wf_b_b.coordinates()
    
    d_waist = d_3_2.to(u.m) + d_2_1.to(u.m) - waist_3.to(u.m)
    plot_angle_array_b = np.arctan(np.array(x_1_b[half_array_length,half_array_length:]/d_waist.value))*180/np.pi
    plot_angle_array_0_b = np.arctan(np.array(x_1_0_b[half_array_length,half_array_length:]/d_waist.value))*180/np.pi
    plot_angle_array_b_b = np.arctan(np.array(x_1_b_b[half_array_length,half_array_length:]/d_waist.value))*180/np.pi
    
y_1, x_1 = wf.coordinates()
z_1 = wf.intensity
array_length = z_1.shape[0]
half_array_length = int(z_1.shape[0]/2)

d_waist = d_3_2.to(u.m) + d_2_1.to(u.m) - waist_3.to(u.m)
print(d_waist)
print(x_1[half_array_length,half_array_length:])

plot_angle_array = np.arctan(np.array(x_1[half_array_length,half_array_length:]/d_waist.value))*180/np.pi
# Out:
# 1.7235738406106718 m
# [0.00000000e+00 1.42058945e-03 2.84117890e-03 ... 1.45042183e+00
#  1.45184242e+00 1.45326301e+00]

# %%
fig3 = plt.figure(figsize=figsize_small)
plt.plot(100*x_1[half_array_length,half_array_length:],10*np.log10(z_1[half_array_length,half_array_length:]),
         label='No baffles, no T-rex',linestyle='--')
if not plot_widths:
    plt.plot(100*x_1_b[half_array_length,half_array_length:],10*np.log10(z_1_b[half_array_length,half_array_length:]),
         label='Baffles, no T-rex',linestyle='--')
    plt.plot(100*x_1_0_b[half_array_length,half_array_length:],10*np.log10(z_1_0_b[half_array_length,half_array_length:]),
         label='No baffles + T-rex')
    plt.plot(100*x_1_b_b[half_array_length,half_array_length:],10*np.log10(z_1_b_b[half_array_length,half_array_length:]),
         label='Baffles + T-rex')
    
plt.axhline(y=-40,label='Target at 15 degrees',linestyle=':')
plt.axvline(x=37,color='black',linestyle=':')
plt.xlabel('Distance from center (cm)')
#plt.xlabel('Distance (cm)')
plt.ylabel('Transmission (dB)')
plt.xlim((0,60))
plt.ylim((-60,5))
#plt.yscale('log')
plt.title('Beam post-primary')
plt.legend()
plt.show()

# %%
fig3 = plt.figure(figsize=figsize_small)
plt.plot(100*x_1[half_array_length,half_array_length:],(z_1[half_array_length,half_array_length:]),
         label='No baffles, no T-rex',linestyle='--')
if not plot_widths:
    plt.plot(100*x_1_b[half_array_length,half_array_length:],(z_1_b[half_array_length,half_array_length:]),
         label='Baffles, no T-rex',linestyle='--')
    plt.plot(100*x_1_0_b[half_array_length,half_array_length:],(z_1_0_b[half_array_length,half_array_length:]),
         label='No baffles + T-rex')
    plt.plot(100*x_1_b_b[half_array_length,half_array_length:],(z_1_b_b[half_array_length,half_array_length:]),
         label='Baffles + T-rex')
#plt.axhline(y=-40,label='Target at 15 degrees',linestyle=':')
plt.xlabel('Distance from center (cm)')
#plt.xlabel('Angle (deg)')
plt.ylabel('Fraction of transmitted power')
plt.xlim((0,5))
#plt.ylim((-60,5))
#plt.yscale('log')
plt.title('Beam post-primary (linear scale)')
plt.legend()
plt.show()

# %%
wf*=primary_obj

plt.figure(figsize=(10,5))
wf.display('both', colorbar=True)
plt.suptitle("Wavefront post-primary", fontsize=18);

# %%
wf_b_b.propagate_fresnel(150*u.m)

# %%
plt.figure(figsize=(10,5))
wf.display('both', colorbar=True)
plt.suptitle("Wavefront post-primary", fontsize=18);

# %%
y_0, x_0 = wf_b_b.coordinates()
z_0 = wf_b_b.intensity
array_length = z_0.shape[0]
half_array_length = int(z_0.shape[0]/2)

d_waist = 100*u.m + d_3_2.to(u.m) + d_2_1.to(u.m) - waist_3.to(u.m)
print(d_waist)
print(x_0[half_array_length,half_array_length:])

plot_angle_array = np.arctan(np.array(x_0[half_array_length,half_array_length:]/d_waist.value))*180/np.pi

fig3 = plt.figure(figsize=figsize_small)
plt.plot(x_0[half_array_length,half_array_length:],10*np.log10(z_0[half_array_length,half_array_length:]),
            label='Baffles + T-Rex')
         
plt.title('Beam at 150m (closest contact by balloon)')
plt.xlabel('Distance from center (cm)')
#plt.xlabel('Angle (deg)')
plt.ylabel('Transmission (dB)')
#plt.xlim((0,15))
#plt.yscale('log')
plt.legend()
plt.show()
# Out:
# 101.72357384061067 m
# [0.00000000e+00 1.24778775e-01 2.49557550e-01 ... 1.27399129e+02
#  1.27523908e+02 1.27648687e+02]

# %%
y_0, x_0 = wf_b_b.coordinates()
z_0 = wf_b_b.intensity
array_length = z_0.shape[0]
half_array_length = int(z_0.shape[0]/2)

d_waist = wf.z-wf.z_w0
print(d_waist)
print(x_0[half_array_length,half_array_length:])

plot_angle_array = np.arctan(np.array(x_0[half_array_length,half_array_length:]/d_waist.value))*180/np.pi

fig3 = plt.figure(figsize=figsize_small)
plt.plot(x_0[half_array_length,half_array_length:],(z_0[half_array_length,half_array_length:]),
            label='Baffles + T-Rex')
         
plt.title('Beam at 150m (closest contact by balloon)')
plt.xlabel('Distance from center (cm)')
#plt.xlabel('Angle (deg)')
plt.ylabel('Transmission (dB)')
#plt.xlim((0,15))
#plt.yscale('log')
plt.legend()
plt.show()
# Out:
# -15.092616662518232 m
# [0.00000000e+00 1.24778775e-01 2.49557550e-01 ... 1.27399129e+02
#  1.27523908e+02 1.27648687e+02]

# %%
wf_b_b.propagate_fresnel(2000*u.m)

wf_b_b.z_w0
# Out:
# <Quantity 0.51877159 m>

# %%
wf_b_b.z
# Out:
# <Quantity 2152.24616744 m>

# %%
wf_b_b.r_c()
# Out:
# <Quantity 2151.72739585 m>

# %%
plt.figure(figsize=(10,5))
wf.display('both', colorbar=True)
plt.suptitle("Wavefront propagated 2000m", fontsize=18);

# %%
y_0, x_0 = wf_b_b.coordinates()
z_0 = wf_b_b.intensity
array_length = z_0.shape[0]
half_array_length = int(z_0.shape[0]/2)

d_waist = (wf_b_b.z-wf_b_b.z_w0).to(u.m)
print(d_waist)
print(x_0[half_array_length,half_array_length:])

plot_angle_array = 60*np.arctan(np.array(x_0[half_array_length,half_array_length:]*.01/d_waist.value))*180/np.pi

fig3 = plt.figure(figsize=figsize_small)
plt.plot(x_0[half_array_length,half_array_length:],(z_0[half_array_length,half_array_length:]),
            label='Baffles + T-Rex')
#plt.plot(plot_angle_array,10*np.log10(z_0[half_array_length,half_array_length:]),
            #label='Baffles + T-Rex')
         
plt.title('Beam at '+str(wf_b_b.z)+' (approximate far-field limit)')
plt.xlabel('Distance from center (cm)')
#plt.xlabel('Angle (deg)')
plt.ylabel('Transmission (dB)')
#plt.xlim((0,15))
#plt.yscale('log')
plt.legend()
plt.show()
# Out:
# 2151.727395852013 m
# [0.00000000e+00 1.76955458e+00 3.53910916e+00 ... 1.80671523e+03
#  1.80848478e+03 1.81025434e+03]

# %%
y_0, x_0 = wf_b_b.coordinates()
z_0 = wf_b_b.intensity
array_length = z_0.shape[0]
half_array_length = int(z_0.shape[0]/2)

d_waist = (wf_b_b.z-wf_b_b.z_w0).to(u.m)
print(d_waist)
print(x_0[half_array_length,half_array_length:])

plot_angle_array = 60*np.arctan(np.array(x_0[half_array_length,half_array_length:]*.01/d_waist.value))*180/np.pi

fig3 = plt.figure(figsize=figsize_small)
#plt.plot(x_0[half_array_length,half_array_length:],10*np.log10(z_0[half_array_length,half_array_length:]),
            #label='Baffles + T-Rex')
plt.plot(plot_angle_array,10*np.log10(z_0[half_array_length,half_array_length:]),
            label='Baffles + T-Rex')
         
plt.title('Beam at '+str(wf_b_b.z)+' (approximate far-field limit)')
plt.xlabel('Angle from center (arcmin)')
#plt.xlabel('Angle (deg)')
plt.ylabel('Transmission (dB)')
plt.xlim((0,10))
plt.ylim((-61,1))
#plt.yscale('log')
plt.legend()
plt.show()
# Out:
# 2151.727395852013 m
# [0.00000000e+00 1.76955458e+00 3.53910916e+00 ... 1.80671523e+03
#  1.80848478e+03 1.81025434e+03]

# %%
y_0, x_0 = wf_b_b.coordinates()
z_0 = wf_b_b.intensity
array_length = z_0.shape[0]
half_array_length = int(z_0.shape[0]/2)

d_waist = (wf_b_b.z-wf_b_b.z_w0).to(u.m)
print(d_waist)
print(x_0[half_array_length,half_array_length:])

plot_angle_array = 60*np.arctan(np.array(x_0[half_array_length,half_array_length:]*.01/d_waist.value))*180/np.pi

fig3 = plt.figure(figsize=figsize_small)
#plt.plot(x_0[half_array_length,half_array_length:],10*np.log10(z_0[half_array_length,half_array_length:]),
            #label='Baffles + T-Rex')
plt.plot(plot_angle_array,(z_0[half_array_length,half_array_length:]),
            label='Baffles + T-Rex')
         
plt.axvline(x=3.5,label='Nominal FWHM',linestyle=':')
plt.title('Beam at '+str(wf_b_b.z)+' (approximate far-field limit)')
plt.xlabel('Distance from center (arcmin)')
#plt.xlabel('Angle (deg)')
plt.ylabel('Transmission (linear)')
plt.xlim((0,10))
#plt.ylim((-61,1))
#plt.yscale('log')
plt.legend()
plt.show()
# Out:
# 2151.727395852013 m
# [0.00000000e+00 1.76955458e+00 3.53910916e+00 ... 1.80671523e+03
#  1.80848478e+03 1.81025434e+03]

# %%
wf_b_b.propagate_fresnel(2000*u.m)

wf_b_b.z_w0
# Out:
# <Quantity 0.51877159 m>

# %%
y_0, x_0 = wf_b_b.coordinates()
z_0 = wf_b_b.intensity
array_length = z_0.shape[0]
half_array_length = int(z_0.shape[0]/2)

d_waist = (wf_b_b.z-wf_b_b.z_w0).to(u.m)
print(d_waist)
print(x_0[half_array_length,half_array_length:])

plot_angle_array = 60*np.arctan(np.array(x_0[half_array_length,half_array_length:]*.01/d_waist.value))*180/np.pi

fig3 = plt.figure(figsize=figsize_small)
#plt.plot(x_0[half_array_length,half_array_length:],10*np.log10(z_0[half_array_length,half_array_length:]),
            #label='Baffles + T-Rex')
plt.plot(plot_angle_array,10*np.log10(z_0[half_array_length,half_array_length:]),
            label='Baffles + T-Rex')
         
plt.title('Beam at '+str(wf_b_b.z)+' (approximate far-field limit)')
plt.xlabel('Angle from center (arcmin)')
#plt.xlabel('Angle (deg)')
plt.ylabel('Transmission (dB)')
plt.xlim((0,10))
plt.ylim((-61,1))
#plt.yscale('log')
plt.legend()
plt.show()
# Out:
# 4151.727395852012 m
# [0.00000000e+00 3.41433039e+00 6.82866077e+00 ... 3.48603132e+03
#  3.48944565e+03 3.49285998e+03]

# %%
y_0, x_0 = wf_b_b.coordinates()
z_0 = wf_b_b.intensity
array_length = z_0.shape[0]
half_array_length = int(z_0.shape[0]/2)

d_waist = (wf_b_b.z-wf_b_b.z_w0).to(u.m)
print(d_waist)
print(x_0[half_array_length,half_array_length:])

plot_angle_array = 60*np.arctan(np.array(x_0[half_array_length,half_array_length:]*.01/d_waist.value))*180/np.pi

fig3 = plt.figure(figsize=figsize_small)
#plt.plot(x_0[half_array_length,half_array_length:],10*np.log10(z_0[half_array_length,half_array_length:]),
            #label='Baffles + T-Rex')
plt.plot(plot_angle_array,(z_0[half_array_length,half_array_length:]),
            label='Baffles + T-Rex')
plt.axvline(x=3.5,label='Nominal FWHM',linestyle=':')

plt.title('Beam at '+str(wf_b_b.z)+' (2x approximate far-field limit)')
plt.xlabel('Distance from center (arcmin)')
#plt.xlabel('Angle (deg)')
plt.ylabel('Transmission (linear)')
plt.xlim((0,10))
#plt.ylim((-61,1))
#plt.yscale('log')
plt.legend()
plt.show()
# Out:
# 4151.727395852012 m
# [0.00000000e+00 3.41433039e+00 6.82866077e+00 ... 3.48603132e+03
#  3.48944565e+03 3.49285998e+03]

# %%
wf_b_b.propagate_fresnel(6000*u.m)

wf_b_b.z_w0
# Out:
# <Quantity 0.51877159 m>

# %%
y_0, x_0 = wf_b_b.coordinates()
z_0 = wf_b_b.intensity
array_length = z_0.shape[0]
half_array_length = int(z_0.shape[0]/2)

d_waist = (wf_b_b.z-wf_b_b.z_w0).to(u.m)
print(d_waist)
print(x_0[half_array_length,half_array_length:])

plot_angle_array = 60*np.arctan(np.array(x_0[half_array_length,half_array_length:]*.01/d_waist.value))*180/np.pi

fig3 = plt.figure(figsize=figsize_small)
#plt.plot(x_0[half_array_length,half_array_length:],10*np.log10(z_0[half_array_length,half_array_length:]),
            #label='Baffles + T-Rex')
plt.plot(plot_angle_array,10*np.log10(z_0[half_array_length,half_array_length:]),
            label='Baffles + T-Rex')
         
plt.title('Beam at '+str(wf_b_b.z)+' (approximate far-field limit)')
plt.xlabel('Angle from center (arcmin)')
#plt.xlabel('Angle (deg)')
plt.ylabel('Transmission (dB)')
plt.xlim((0,10))
plt.ylim((-61,1))
#plt.yscale('log')
plt.legend()
plt.show()
# Out:
# 10151.727395852013 m
# [0.00000000e+00 8.34865780e+00 1.66973156e+01 ... 8.52397962e+03
#  8.53232827e+03 8.54067693e+03]

# %%
y_0, x_0 = wf_b_b.coordinates()
z_0 = wf_b_b.intensity
array_length = z_0.shape[0]
half_array_length = int(z_0.shape[0]/2)

d_waist = (wf_b_b.z-wf_b_b.z_w0).to(u.m)
print(d_waist)
print(x_0[half_array_length,half_array_length:])

plot_angle_array = 60*np.arctan(np.array(x_0[half_array_length,half_array_length:]*.01/d_waist.value))*180/np.pi

fig3 = plt.figure(figsize=figsize_small)
#plt.plot(x_0[half_array_length,half_array_length:],10*np.log10(z_0[half_array_length,half_array_length:]),
            #label='Baffles + T-Rex')
plt.plot(plot_angle_array,(z_0[half_array_length,half_array_length:]),
            label='Baffles + T-Rex')
plt.axvline(x=3.5,label='Nominal FWHM',linestyle=':')

plt.title('Beam at '+str(wf_b_b.z)+' (2x approximate far-field limit)')
plt.xlabel('Distance from center (arcmin)')
#plt.xlabel('Angle (deg)')
plt.ylabel('Transmission (linear)')
plt.xlim((0,10))
#plt.ylim((-61,1))
#plt.yscale('log')
plt.legend()
plt.show()
# Out:
# 10151.727395852013 m
# [0.00000000e+00 8.34865780e+00 1.66973156e+01 ... 8.52397962e+03
#  8.53232827e+03 8.54067693e+03]

# %%
#plot_widths=True
if not plot_widths:
    width_array = np.loadtxt('no_baffle_width_array.txt')
distance_array = np.linspace(0,len(width_array)/100,len(width_array))

d_lens_3 = d_lens_3
d_lens_2 = d_lens_3 + d_3_2
d_lens_1 = d_lens_2 + d_2_1

print("Distances:")
print("\tLens-tertiary: %.3f cm" %d_lens_3.value)
print("\tLens-secondary: %.3f cm" %d_lens_2.value)
print("\tLens-primary: %.3f cm" %d_lens_1.value)

for i,width in enumerate(width_array):
    width_array[i] = width #.value

#plt.figure(figsize=(10,6))
plt.figure(figsize=(6,4))
plt.plot(distance_array,width_array,color='black')
plt.xlabel('Distance from lens (cm)')
plt.ylabel('Gaussian beam width (cm)')
plt.axvline(x=0,linewidth=1, color='orange',linestyle='--',label='Lens position')
plt.axvline(x=(d_lens_3).value,linewidth=1, color='yellow',linestyle='--',label='Tertiary position')
plt.axvline(x=(d_lens_2).value,linewidth=1, color='blue',linestyle='--',label='Secondary position')
plt.axvline(x=(d_lens_1).value,linewidth=1, color='indigo',linestyle='--',label='Primary position')
plt.legend()
plt.show()
# Out:
# Distances:
# 	Lens-tertiary: 33.060 cm
# 	Lens-secondary: 119.622 cm
# 	Lens-primary: 224.617 cm

# %% [markdown]
# ####
